# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import ipynb

# %%
from ipynb.fs.full.Functions import splitAll
from ipynb.fs.full.Functions import fit_model

# %% [markdown]
# # Get data

# %%
df = pd.read_excel('dataset_ML_govvies_cleaned.xlsx')
X_train, Y_train, X_val, Y_val, X_test, Y_test = splitAll(df)

# %% [markdown]
# # XGB

# %%
# XGBoost param grid
param_grid = {
'max_depth': [3,4,5,6],
'n_estimators': [200, 300, 400, 500],
'learning_rate': [0.1,0.2],
}

Y_pred_oos = fit_model(X_train, Y_train, X_val, Y_val, X_test, Y_test, 'XGB', param_grid)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [4], line 8
#       1 # XGBoost param grid
#       2 param_grid = {
#       3 'max_depth': [3,4,5,6],
#       4 'n_estimators': [200, 300, 400, 500],
#       5 'learning_rate': [0.1,0.2],
#       6 }
# ----> 8 fit_model(X_train, Y_train, X_val, Y_val, X_test, Y_test, 'XGB', param_grid)
#
# File c:\Users\sunny\Downloads\Master QF\3 Seminar Case\Robeco\Code\Functions.ipynb:146, in fit_model(X_train, Y_train, X_val, Y_val, X_test, Y_test, modelname, params)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": null,
#       6    "metadata": {},
#       7    "outputs": [],
#       8    "source": []
#       9   },
#      10   {
#      11    "attachments": {},
#      12    "cell_type": "markdown",
#      13    "metadata": {},
#      14    "source": [
#      15     "# Imports"
#      16    ]
#      17   },
#      18   {
#      19    "cell_type": "code",
#      20    "execution_count": 14,
#      21    "metadata": {},
#      22    "outputs": [],
#      23    "source": [
#      24     "import pandas as pd\n",
#      25     "import numpy as np\n",
#      26     "from sklearn.preprocessing import MinMaxScaler\n",
#      27     "from sklearn.metrics import mean_squared_error, r2_score\n",
#      28     "from sklearn.metrics import classification_report\n",
#      29     "from sklearn.model_selection import GridSearchCV\n",
#      30     "\n",
#      31     "from sklearn.linear_model import LinearRegression\n",
#      32     "from sklearn.ensemble import RandomForestRegressor\n",
#      33     "from xgboost import XGBRegressor"
#      34    ]
#      35   },
#      36   {
#      37    "attachments": {},
#      38    "cell_type": "markdown",
#      39    "metadata": {},
#      40    "source": [
#      41     "# Split data to X_train, X_val, X_test, Y_train, Y_val, Y_test"
#      42    ]
#      43   },
#      44   {
#      45    "cell_type": "code",
#      46    "execution_count": 15,
#      47    "metadata": {},
#      48    "outputs": [],
#      49    "source": [
#      50     "def splitDf(df, non_X_cols = ['Unnamed: 0','Date','Bond','Return_PD']):\n",
#      51     "\n",
#      52     "    # normalize all columns which is not in non_X_cols to -1 and 1\n",
#      53     "    scaler = MinMaxScaler(feature_range=(-1, 1))\n",
#      54     "    for col in df.columns:\n",
#      55     "        if col not in non_X_cols:\n",
#      56     "            df[col] = scaler.fit_transform(df[[col]])\n",
#      57     "\n",
#      58     "\n",
#      59     "    # get the unique dates of df_cleaned column: Date\n",
#      60     "    dates = df['Date'].unique()\n",
#      61     "    middleDate = dates[round(0.5 * len(dates))]\n",
#      62     "    seventypercentileDate = dates[round(0.7 * len(dates))]\n",
#      63     "\n",
#      64     "        # get data until middleDate of df_cleaned\n",
#      65     "    df_train = df[df['Date'] < middleDate]\n",
#      66     "    # get data from middleDate of df_cleaned\n",
#      67     "    df_val = df[df['Date'] >= middleDate]\n",
#      68     "    df_val = df_val[df_val['Date'] < seventypercentileDate]\n",
#      69     "    # get data from seventypercentileDate of df_cleaned\n",
#      70     "    df_test = df[df['Date'] >= seventypercentileDate]\n",
#      71     "\n",
#      72     "    return df_train, df_val, df_test"
#      73    ]
#      74   },
#      75   {
#      76    "cell_type": "code",
#      77    "execution_count": 16,
#      78    "metadata": {},
#      79    "outputs": [],
#      80    "source": [
#      81     "def splitToXY(df, non_X_cols = ['Unnamed: 0','Date','Bond','Return_PD']):\n",
#      82     "\n",
#      83     "    # define np array of X and Y\n",
#      84     "    # X has dimension len(df)/42 x 85\n",
#      85     "    # Y has dimension len(df)/42 x 1\n",
#      86     "\n",
#      87     "    X = np.zeros((len(df), 85))\n",
#      88     "    Y = np.zeros((len(df), 1))\n",
#      89     "\n",
#      90     "    df_X = df.drop(columns= non_X_cols)\n",
#      91     "    df_Y = df['Return_PD']\n",
#      92     "\n",
#      93     "    # Assign df_X to X\n",
#      94     "    for i in range(len(df_X)):\n",
#      95     "        X[i] = df_X.iloc[i].values\n",
#      96     "        Y[i] = df_Y.iloc[i]\n",
#      97     "        \n",
#      98     "    return X, Y"
#      99    ]
#     100   },
#     101   {
#     102    "cell_type": "code",
#     103    "execution_count": 17,
#     104    "metadata": {},
#     105    "outputs": [],
#     106    "source": [
#     107     "def splitAll(df):\n",
#     108     "    df_train, df_val, df_test = splitDf(df)\n",
#     109     "\n",
#     110     "    X_train, Y_train = splitToXY(df_train)\n",
#     111     "    X_val, Y_val = splitToXY(df_val)\n",
#     112     "    X_test, Y_test = splitToXY(df_test)\n",
#     113     "\n",
#     114     "    return X_train, Y_train, X_val, Y_val, X_test, Y_test"
#     115    ]
#     116   },
#     117   {
#     118    "attachments": {},
#     119    "cell_type": "markdown",
#     120    "metadata": {},
#     121    "source": [
#     122     "# Bonds names"
#     123    ]
#     124   },
#     125   {
#     126    "cell_type": "code",
#     127    "execution_count": 18,
#     128    "metadata": {},
#     129    "outputs": [],
#     130    "source": [
#     131     "def bondsNames(df):\n",
#     132     "    df_bonds = df['Bond'][:35]\n",
#     133     "    return df_bonds"
#     134    ]
#     135   },
#     136   {
#     137    "attachments": {},
#     138    "cell_type": "markdown",
#     139    "metadata": {},
#     140    "source": [
#     141     "# Model fit"
#     142    ]
#     143   },
#     144   {
#     145    "cell_type": "code",
# --> 146    "execution_count": 19,
#     147    "metadata": {},
#     148    "outputs": [],
#     149    "source": [
#     150     "def evaluate_model(Y_pred, Y_test):\n",
#     151     "    \n",
#     152     "    # R squared score\n",
#     153     "    r2_test = r2_score(Y_test, Y_pred)\n",
#     154     "    \n",
#     155     "    return r2_test"
#     156    ]
#     157   },
#     158   {
#     159    "cell_type": "code",
#     160    "execution_count": 20,
#     161    "metadata": {},
#     162    "outputs": [],
#     163    "source": [
#     164     "def tuned_model(X_train, Y_train, X_val, Y_val, modelname, params):\n",
#     165     "\n",
#     166     "    r2_score = -100\n",
#     167     "    best_model = None\n",
#     168     "\n",
#     169     "    if modelname == 'OLS-All':\n",
#     170     "        best_model = LinearRegression()\n",
#     171     "        best_model.fit(X_train, Y_train.ravel())\n",
#     172     "\n",
#     173     "    if modelname == 'RF':\n",
#     174     "        for depth in params['max_depth']:\n",
#     175     "            for features in params['max_features']:\n",
#     176     "                model = RandomForestRegressor(max_depth = int(depth), n_estimators = 300, max_features = int(features))\n",
#     177     "                model.fit(X_train, Y_train.ravel())\n",
#     178     "                Y_pred = model.predict(X_val)\n",
#     179     "                r2_test = evaluate_model(Y_pred, Y_val)\n",
#     180     "                if r2_test > r2_score:\n",
#     181     "                    r2_score = r2_test\n",
#     182     "                    best_model = model\n",
#     183     "\n",
#     184     "\n",
#     185     "    if modelname == 'XGB':\n",
#     186     "        for depth in params['max_depth']:\n",
#     187     "            for n_estimator in params['n_estimators']:\n",
#     188     "                for lr in params['learning_rate']:\n",
#     189     "                    model = XGBRegressor(max_depth = int(depth), n_estimators = int(n_estimator), learning_rate = lr)\n",
#     190     "                    model.fit(X_train, Y_train.ravel())\n",
#     191     "                    Y_pred = model.predict(X_val)\n",
#     192     "                    r2_test = evaluate_model(Y_pred, Y_val)\n",
#     193     "                    if r2_test > r2_score:\n",
#     194     "                        r2_score = r2_test\n",
#     195     "                        best_model = model\n",
#     196     "    \n",
#     197     "    \n",
#     198     "    return best_model"
#     199    ]
#     200   },
#     201   {
#     202    "cell_type": "code",
#     203    "execution_count": 21,
#     204    "metadata": {},
#     205    "outputs": [],
#     206    "source": [
#     207     "def fit_model(X_train, Y_train, X_val, Y_val, X_test, Y_test, modelname, params):\n",
#     208     "\n",
#     209     "    model = tuned_model(X_train, Y_train, X_val, Y_val, modelname = modelname, params = params)\n",
#     210     "    counter = 0\n",
#     211     "    Y_pred = np.zeros(Y_test.shape[0])\n",
#     212     "\n",
#     213     "    for i in range(len(X_test)):\n",
#     214     "        Y_pred[i] = model.predict(X_test[i].reshape(1, -1))\n",
#     215     "        counter += 1\n",
#     216     "        if counter % (12*35) == 0:\n",
#     217     "            X_train = np.concatenate((X_train, X_val[:i]), axis=0)\n",
#     218     "            Y_train = np.concatenate((Y_train, Y_val[:i]), axis=0)\n",
#     219     "            X_val = X_val[i:]\n",
#     220     "            X_val = np.concatenate((X_val, X_test[:i]), axis=0)\n",
#     221     "            Y_val = Y_val[i:]\n",
#     222     "            Y_val = np.concatenate((Y_val, Y_test[:i]), axis=0)\n",
#     223     "            model = tuned_model(X_train, Y_train, X_val, Y_val, modelname = modelname, params = params)\n",
#     224     "\n",
#     225     "            # print percentage of run time\n",
#     226     "            print('Percentage of run time: ', round(counter/len(X_test)*100, 2), '%')\n",
#     227     "\n",
#     228     "    r2_test = evaluate_model(Y_pred, Y_test)\n",
#     229     "    print('R2 score: ', r2_test)\n"
#     230    ]
#     231   },
#     232   {
#     233    "cell_type": "code",
#     234    "execution_count": null,
#     235    "metadata": {},
#     236    "outputs": [],
#     237    "source": []
#     238   }
#     239  ],
#     240  "metadata": {
#     241   "kernelspec": {
#     242    "display_name": "Python 3",
#     243    "language": "python",
#     244    "name": "python3"
#     245   },
#     246   "language_info": {
#     247    "codemirror_mode": {
#     248     "name": "ipython",
#     249     "version": 3
#     250    },
#     251    "file_extension": ".py",
#     252    "mimetype": "text/x-python",
#     253    "name": "python",
#     254    "nbconvert_exporter": "python",
#     255    "pygments_lexer": "ipython3",
#     256    "version": "3.11.0"
#     257   },
#     258   "orig_nbformat": 4,
#     259   "vscode": {
#     260    "interpreter": {
#     261     "hash": "db35a02fd5d0ba4c5963f2cd8d92bdb63f7f3bde1f98582f1ef84023082d273b"
#     262    }
#     263   }
#     264  },
#     265  "nbformat": 4,
#     266  "nbformat_minor": 2
#     267 }
#
# File c:\Users\sunny\Downloads\Master QF\3 Seminar Case\Robeco\Code\Functions.ipynb:120, in tuned_model(X_train, Y_train, X_val, Y_val, modelname, params)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": null,
#       6    "metadata": {},
#       7    "outputs": [],
#       8    "source": []
#       9   },
#      10   {
#      11    "attachments": {},
#      12    "cell_type": "markdown",
#      13    "metadata": {},
#      14    "source": [
#      15     "# Imports"
#      16    ]
#      17   },
#      18   {
#      19    "cell_type": "code",
#      20    "execution_count": 14,
#      21    "metadata": {},
#      22    "outputs": [],
#      23    "source": [
#      24     "import pandas as pd\n",
#      25     "import numpy as np\n",
#      26     "from sklearn.preprocessing import MinMaxScaler\n",
#      27     "from sklearn.metrics import mean_squared_error, r2_score\n",
#      28     "from sklearn.metrics import classification_report\n",
#      29     "from sklearn.model_selection import GridSearchCV\n",
#      30     "\n",
#      31     "from sklearn.linear_model import LinearRegression\n",
#      32     "from sklearn.ensemble import RandomForestRegressor\n",
#      33     "from xgboost import XGBRegressor"
#      34    ]
#      35   },
#      36   {
#      37    "attachments": {},
#      38    "cell_type": "markdown",
#      39    "metadata": {},
#      40    "source": [
#      41     "# Split data to X_train, X_val, X_test, Y_train, Y_val, Y_test"
#      42    ]
#      43   },
#      44   {
#      45    "cell_type": "code",
#      46    "execution_count": 15,
#      47    "metadata": {},
#      48    "outputs": [],
#      49    "source": [
#      50     "def splitDf(df, non_X_cols = ['Unnamed: 0','Date','Bond','Return_PD']):\n",
#      51     "\n",
#      52     "    # normalize all columns which is not in non_X_cols to -1 and 1\n",
#      53     "    scaler = MinMaxScaler(feature_range=(-1, 1))\n",
#      54     "    for col in df.columns:\n",
#      55     "        if col not in non_X_cols:\n",
#      56     "            df[col] = scaler.fit_transform(df[[col]])\n",
#      57     "\n",
#      58     "\n",
#      59     "    # get the unique dates of df_cleaned column: Date\n",
#      60     "    dates = df['Date'].unique()\n",
#      61     "    middleDate = dates[round(0.5 * len(dates))]\n",
#      62     "    seventypercentileDate = dates[round(0.7 * len(dates))]\n",
#      63     "\n",
#      64     "        # get data until middleDate of df_cleaned\n",
#      65     "    df_train = df[df['Date'] < middleDate]\n",
#      66     "    # get data from middleDate of df_cleaned\n",
#      67     "    df_val = df[df['Date'] >= middleDate]\n",
#      68     "    df_val = df_val[df_val['Date'] < seventypercentileDate]\n",
#      69     "    # get data from seventypercentileDate of df_cleaned\n",
#      70     "    df_test = df[df['Date'] >= seventypercentileDate]\n",
#      71     "\n",
#      72     "    return df_train, df_val, df_test"
#      73    ]
#      74   },
#      75   {
#      76    "cell_type": "code",
#      77    "execution_count": 16,
#      78    "metadata": {},
#      79    "outputs": [],
#      80    "source": [
#      81     "def splitToXY(df, non_X_cols = ['Unnamed: 0','Date','Bond','Return_PD']):\n",
#      82     "\n",
#      83     "    # define np array of X and Y\n",
#      84     "    # X has dimension len(df)/42 x 85\n",
#      85     "    # Y has dimension len(df)/42 x 1\n",
#      86     "\n",
#      87     "    X = np.zeros((len(df), 85))\n",
#      88     "    Y = np.zeros((len(df), 1))\n",
#      89     "\n",
#      90     "    df_X = df.drop(columns= non_X_cols)\n",
#      91     "    df_Y = df['Return_PD']\n",
#      92     "\n",
#      93     "    # Assign df_X to X\n",
#      94     "    for i in range(len(df_X)):\n",
#      95     "        X[i] = df_X.iloc[i].values\n",
#      96     "        Y[i] = df_Y.iloc[i]\n",
#      97     "        \n",
#      98     "    return X, Y"
#      99    ]
#     100   },
#     101   {
#     102    "cell_type": "code",
#     103    "execution_count": 17,
#     104    "metadata": {},
#     105    "outputs": [],
#     106    "source": [
#     107     "def splitAll(df):\n",
#     108     "    df_train, df_val, df_test = splitDf(df)\n",
#     109     "\n",
#     110     "    X_train, Y_train = splitToXY(df_train)\n",
#     111     "    X_val, Y_val = splitToXY(df_val)\n",
#     112     "    X_test, Y_test = splitToXY(df_test)\n",
#     113     "\n",
#     114     "    return X_train, Y_train, X_val, Y_val, X_test, Y_test"
#     115    ]
#     116   },
#     117   {
#     118    "attachments": {},
#     119    "cell_type": "markdown",
# --> 120    "metadata": {},
#     121    "source": [
#     122     "# Bonds names"
#     123    ]
#     124   },
#     125   {
#     126    "cell_type": "code",
#     127    "execution_count": 18,
#     128    "metadata": {},
#     129    "outputs": [],
#     130    "source": [
#     131     "def bondsNames(df):\n",
#     132     "    df_bonds = df['Bond'][:35]\n",
#     133     "    return df_bonds"
#     134    ]
#     135   },
#     136   {
#     137    "attachments": {},
#     138    "cell_type": "markdown",
#     139    "metadata": {},
#     140    "source": [
#     141     "# Model fit"
#     142    ]
#     143   },
#     144   {
#     145    "cell_type": "code",
#     146    "execution_count": 19,
#     147    "metadata": {},
#     148    "outputs": [],
#     149    "source": [
#     150     "def evaluate_model(Y_pred, Y_test):\n",
#     151     "    \n",
#     152     "    # R squared score\n",
#     153     "    r2_test = r2_score(Y_test, Y_pred)\n",
#     154     "    \n",
#     155     "    return r2_test"
#     156    ]
#     157   },
#     158   {
#     159    "cell_type": "code",
#     160    "execution_count": 20,
#     161    "metadata": {},
#     162    "outputs": [],
#     163    "source": [
#     164     "def tuned_model(X_train, Y_train, X_val, Y_val, modelname, params):\n",
#     165     "\n",
#     166     "    r2_score = -100\n",
#     167     "    best_model = None\n",
#     168     "\n",
#     169     "    if modelname == 'OLS-All':\n",
#     170     "        best_model = LinearRegression()\n",
#     171     "        best_model.fit(X_train, Y_train.ravel())\n",
#     172     "\n",
#     173     "    if modelname == 'RF':\n",
#     174     "        for depth in params['max_depth']:\n",
#     175     "            for features in params['max_features']:\n",
#     176     "                model = RandomForestRegressor(max_depth = int(depth), n_estimators = 300, max_features = int(features))\n",
#     177     "                model.fit(X_train, Y_train.ravel())\n",
#     178     "                Y_pred = model.predict(X_val)\n",
#     179     "                r2_test = evaluate_model(Y_pred, Y_val)\n",
#     180     "                if r2_test > r2_score:\n",
#     181     "                    r2_score = r2_test\n",
#     182     "                    best_model = model\n",
#     183     "\n",
#     184     "\n",
#     185     "    if modelname == 'XGB':\n",
#     186     "        for depth in params['max_depth']:\n",
#     187     "            for n_estimator in params['n_estimators']:\n",
#     188     "                for lr in params['learning_rate']:\n",
#     189     "                    model = XGBRegressor(max_depth = int(depth), n_estimators = int(n_estimator), learning_rate = lr)\n",
#     190     "                    model.fit(X_train, Y_train.ravel())\n",
#     191     "                    Y_pred = model.predict(X_val)\n",
#     192     "                    r2_test = evaluate_model(Y_pred, Y_val)\n",
#     193     "                    if r2_test > r2_score:\n",
#     194     "                        r2_score = r2_test\n",
#     195     "                        best_model = model\n",
#     196     "    \n",
#     197     "    \n",
#     198     "    return best_model"
#     199    ]
#     200   },
#     201   {
#     202    "cell_type": "code",
#     203    "execution_count": 21,
#     204    "metadata": {},
#     205    "outputs": [],
#     206    "source": [
#     207     "def fit_model(X_train, Y_train, X_val, Y_val, X_test, Y_test, modelname, params):\n",
#     208     "\n",
#     209     "    model = tuned_model(X_train, Y_train, X_val, Y_val, modelname = modelname, params = params)\n",
#     210     "    counter = 0\n",
#     211     "    Y_pred = np.zeros(Y_test.shape[0])\n",
#     212     "\n",
#     213     "    for i in range(len(X_test)):\n",
#     214     "        Y_pred[i] = model.predict(X_test[i].reshape(1, -1))\n",
#     215     "        counter += 1\n",
#     216     "        if counter % (12*35) == 0:\n",
#     217     "            X_train = np.concatenate((X_train, X_val[:i]), axis=0)\n",
#     218     "            Y_train = np.concatenate((Y_train, Y_val[:i]), axis=0)\n",
#     219     "            X_val = X_val[i:]\n",
#     220     "            X_val = np.concatenate((X_val, X_test[:i]), axis=0)\n",
#     221     "            Y_val = Y_val[i:]\n",
#     222     "            Y_val = np.concatenate((Y_val, Y_test[:i]), axis=0)\n",
#     223     "            model = tuned_model(X_train, Y_train, X_val, Y_val, modelname = modelname, params = params)\n",
#     224     "\n",
#     225     "            # print percentage of run time\n",
#     226     "            print('Percentage of run time: ', round(counter/len(X_test)*100, 2), '%')\n",
#     227     "\n",
#     228     "    r2_test = evaluate_model(Y_pred, Y_test)\n",
#     229     "    print('R2 score: ', r2_test)\n"
#     230    ]
#     231   },
#     232   {
#     233    "cell_type": "code",
#     234    "execution_count": null,
#     235    "metadata": {},
#     236    "outputs": [],
#     237    "source": []
#     238   }
#     239  ],
#     240  "metadata": {
#     241   "kernelspec": {
#     242    "display_name": "Python 3",
#     243    "language": "python",
#     244    "name": "python3"
#     245   },
#     246   "language_info": {
#     247    "codemirror_mode": {
#     248     "name": "ipython",
#     249     "version": 3
#     250    },
#     251    "file_extension": ".py",
#     252    "mimetype": "text/x-python",
#     253    "name": "python",
#     254    "nbconvert_exporter": "python",
#     255    "pygments_lexer": "ipython3",
#     256    "version": "3.11.0"
#     257   },
#     258   "orig_nbformat": 4,
#     259   "vscode": {
#     260    "interpreter": {
#     261     "hash": "db35a02fd5d0ba4c5963f2cd8d92bdb63f7f3bde1f98582f1ef84023082d273b"
#     262    }
#     263   }
#     264  },
#     265  "nbformat": 4,
#     266  "nbformat_minor": 2
#     267 }
#
# File c:\Users\sunny\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File c:\Users\sunny\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\sklearn.py:1025, in XGBModel.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1014     obj = None
#    1016 (
#    1017     model,
#    1018     metric,
#    (...)
#    1023     xgb_model, eval_metric, params, early_stopping_rounds, callbacks
#    1024 )
# -> 1025 self._Booster = train(
#    1026     params,
#    1027     train_dmatrix,
#    1028     self.get_num_boosting_rounds(),
#    1029     evals=evals,
#    1030     early_stopping_rounds=early_stopping_rounds,
#    1031     evals_result=evals_result,
#    1032     obj=obj,
#    1033     custom_metric=metric,
#    1034     verbose_eval=verbose,
#    1035     xgb_model=model,
#    1036     callbacks=callbacks,
#    1037 )
#    1039 self._set_evaluation_result(evals_result)
#    1040 return self
#
# File c:\Users\sunny\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File c:\Users\sunny\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\training.py:185, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     183 if cb_container.before_iteration(bst, i, dtrain, evals):
#     184     break
# --> 185 bst.update(dtrain, i, obj)
#     186 if cb_container.after_iteration(bst, i, dtrain, evals):
#     187     break
#
# File c:\Users\sunny\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\core.py:1918, in Booster.update(self, dtrain, iteration, fobj)
#    1915 self._validate_dmatrix_features(dtrain)
#    1917 if fobj is None:
# -> 1918     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1919                                             ctypes.c_int(iteration),
#    1920                                             dtrain.handle))
#    1921 else:
#    1922     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:
